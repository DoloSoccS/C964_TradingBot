# %%
import datetime
import yfinance as yf
import numpy as np
from Database.MongoDB_Connection import start_db
import pandas as pd
import time
from datetime import datetime, timedelta, date
import talib as ta
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Connect to MongoDB
db = start_db()
db
print(db)
# Out:
# ['C964_Database', 'admin', 'config', 'local']
# Test entry exists
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'C964_Database')

# %%
#Tickers for training
print("Reading list of tickers to be loaded.")

tickers = [
    "AAL", "AAPL", "ABEV", "ACHR", "ADBE", "ADT", "ADSK", "ALGN", "ALNY", "AMAT",
    "AMCR", "AMD", "AMZN", "ANET", "APH", "ASML", "AUR", "AVGO", "AXP", "BA",
    "BAC", "BAX", "BB", "BBD", "BDX", "BIIB", "BK", "BKNG", "BLK", "BMY",
    "BTG", "C", "CAT", "CCL", "CDE", "CHTR", "CI", "CINF", "CMCSA", "CMI",
    "CNH", "COF", "COP", "COST", "CPNG", "CRM", "CSCO", "CSX", "CTAS", "CVS",
    "CVX", "CX", "D", "DD", "DE", "DG", "DHR", "DIS", "DJT", "DOV",
    "DTE", "DUK", "EMR", "ENPH", "EOG", "EQIX", "ERIC", "ETN", "EXC", "F",
    "FANG", "FAST", "FDX", "FE", "FIS", "FISV", "GAP", "GE", "GGB", "GILD",
    "GIS", "GLW", "GM", "GME", "GOOG", "GOOGL", "GRAB", "GS", "HAL", "HBAN",
    "HD", "HIMS", "HL", "HLN", "HOLX", "HON", "HOOD", "HPQ", "HPE", "IBM",
    "IAG", "ICE", "ILMN", "INFA", "INTC", "INTU", "IONQ", "ISRG", "ITUB", "ITW",
    "JNPR", "JWN", "K", "KGC", "KEY", "KLAC", "KMB", "KMI", "KO", "KR",
    "LCID", "LIN", "LLY", "LMT", "LOW", "LRCX", "LUMN", "LUV", "LYFT", "LYG",
    "MA", "MARA", "MCD", "MDLZ", "MDT", "MET", "MMM", "MO", "MRK", "MRVL",
    "MS", "MSFT", "MSI", "MTB", "MU", "NEE", "NEM", "NFLX", "NIO", "NKE",
    "NKLA", "NOK", "NOV", "NRG", "NSC", "NTAP", "NVDA", "NU", "NXE", "OKLO",
    "PDD", "PCG", "PFE", "PLTR", "PONY", "PSLV", "PTEN", "QBTS", "RGTI", "RIOT",
    "RIG", "RIVN", "RKLB", "SOUN", "SMCI", "SMR", "SNAP", "SOFI", "T", "TEM",
    "TEVA", "TSLA", "UBER", "UAA", "UEC", "UNH", "VALE", "VOD", "VTRS", "WBD",
    "WMB", "WMT", "WRD", "X"
]
# Out:
# Reading list of tickers to be loaded.

# %%
# Entering documents into database based on ticker symbols above. More fields will be added once the database is loaded with the initial ticker data.

print("Inserting documents into MongoDB.")

for ticker in tickers:
    try:
        # Gather 10 year historical data in 1-year intervals. progress=False is to stop the display of the progress bar while downloading
        data = yf.download(ticker, period="10y", interval="1d", progress=False, auto_adjust=False)

        if not data.empty:
            # Move 'Date' from index to column
            data.reset_index(inplace=True)
            data["Ticker"] = ticker

            # Convert NaNs to None (MongoDB does not accept NaN)
            data.replace({np.nan: None}, inplace=True)

            # This prevents the data from being formatted incorrectly. Each value needs to be a string.
            if isinstance(data.columns, pd.MultiIndex):
                data.columns = ['_'.join(filter(None, col)).strip() for col in data.columns]

            # Create dictionary of documents to enter into database
            newDocs = data.to_dict("records")

            # Insert into MongoDB
            db.Finance_Data.insert_many(newDocs)
            print(f"Inserted {len(newDocs)} attributes for {ticker}.")

        # Timer to prevent rate limit on yfinance. This limiter will cause a multi-day lockout.
        time.sleep(1.5)
    except Exception as e:
        print(f"{ticker} had an error being inserted: {e}")

# %%
# Restructuring the document fields in the database. From the yfinance API the fields are labeled as "close_{ticker}". This needed to be changed since the subsequent actions need to be easily manipulated across all tickers. Having them be uniform will make that process easier.
print("Transforming field names.")

rename_fields = ["Open", "High", "Low", "Close", "Volume"]
tickers = db.Finance_Data.distinct("Ticker")

for ticker in tickers:

    for field in rename_fields:
        old_field = f"{field}_{ticker}"
        new_field = field
        db.Finance_Data.update_many(
            {old_field: {"$exists": True}},
            {"$rename": {old_field: new_field}}
        )
    print(f"Renamed fields for {ticker}")

# %%
"""
The next few sections will be for adding the additional columns to the database documents.
The first one will add a "Success" column. This will be based on whether the stock's "Close" value is greater than the "Open" value.
This is the only one that will require a manual calculation to be performed.
Next, the "Sentiment Score" column will be added using the nltk package. This library aggregates a list of related news articles pertaining to the ticker symbol in question. A value will be produced from -1 to +1.
The columns for SMA, EMA, RSI and MACD will use a group of values from the ticker symbol in order to make the calculations.
This action will be performed using the TA-lib package.
"""

# %%
# Adding the 'Success' column
print("Adding Success column to database.")

# Gather each documents Open and Close value. If Open < Close, then Success = 1. Otherwise, Success = 0.
for doc in db.Finance_Data.find():
    doc_close = doc.get("Close")
    doc_open = doc.get("Open")

    if doc_close is not None and doc_open is not None:
        success_flag = 1 if doc_close > doc_open else 0
        db.Finance_Data.update_one(
            {"_id": doc["_id"]},
            {"$set": {"Success": success_flag}}
        )

# %%
# Adding the 'Sentiment Score' column
print("Adding sentiment score for each ticker.")

nltk.download('vader_lexicon')

# Initialize Sentiment Analyzer for using model against related news articles
sia = SentimentIntensityAnalyzer()

# Get list of tickers
#tickers = db.Finance_Data.distinct("Ticker")
tickers = ["AAPL", "NVDA", "X"]

for ticker_symbol in tickers:
    try:

        # Gets all the news items for the ticker symbol
        news_items = yf.Ticker(ticker_symbol).news
        print(f"First Check. See if there are news items : Ticker: {ticker_symbol}, News : {len(news_items)}")


        # Will be used to store a dictionary of dates:news summaries
        news_articles = []

        for item in news_items:
            content = item.get("content", {})
            if "summary" in content and "pubDate" in content:
                print("adding articles")
                article_date = datetime.fromisoformat(content["pubDate"].replace("Z", "")).date()
                news_articles.append({"Article_Date" : article_date, "Summary": content["summary"]})
            else:
                print("There's the issue getting the summary or pubDate")


        # Calculate sentiment from the last 60 days. The time variable maybe a bit difficult to gather with the date limitations in MongoDB along with the limitations from yfinance.
        docs = db.Finance_Data.find({"Ticker": ticker_symbol})
        for doc in docs:
            #print(f"Second check on date : Doc ID: {doc['_id']}, Date: {doc.get('Date')}")
            doc_date = doc.get("Date")

            if isinstance(doc_date, datetime):
                doc_date = doc_date.date()
            elif isinstance(doc_date, str):
                try:
                    doc_date = datetime.strptime(doc_date, "%Y-%m-%d").date()
                except:
                    print("meh")

            start_range = doc_date - timedelta(days=60)
            print(start_range)
            # Will be used to store the compound score of the sentiment for all documents for the specific ticker
            compound_scores = []
            for item in news_articles:


                                # Debugging outputs
                print(f"start_range: {start_range}, doc_date: {doc_date}, article_date: {item['Article_Date']}")


                # Skip if date is wrong
                if not isinstance(item["Article_Date"], date):
                    print("Invalid article date format. Skipping.")
                    continue




                if start_range <= item["Article_Date"] < doc_date:
                    print(f"Checking article date: {item['Article_Date']}, range: {start_range} to {doc_date}")
                    sentiment = sia.polarity_scores(item["Summary"])
                    compound_scores.append(sentiment["compound"])

            if compound_scores:
                average_sentiment = sum(compound_scores) / len(compound_scores)
            else:
                average_sentiment = 0.0

            # Update all documents for this ticker with sentiment (or just latest if preferred)
            db.Finance_Data.update_one(
                    {"_id": doc["_id"]},
                    {"$set": {"Sentiment": average_sentiment}}
                )

        # If there is no news available for given ticker, set default sentiment to neutral (0.0).
    except Exception as e:
        print(f"Error processing {ticker_symbol}: {e}. Default sentiment value is 0.0 - 0.1.")
        db.Finance_Data.update_many(
            {"Ticker": ticker_symbol},
            {"$set": {"Sentiment": 0.1}}
        )
# Out:
# Adding sentiment score for each ticker.
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\dhous\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# First Check. See if there are news items : Ticker: AAPL, News : 10
# adding articles
# adding articles
# adding articles
# adding articles
# adding articles
# adding articles
# adding articles
# adding articles
# adding articles
# adding articles
# 2015-03-30
# start_range: 2015-03-30, doc_date: 2015-05-29, article_date: 2025-06-06
# start_range: 2015-03-30, doc_date: 2015-05-29, article_date: 2025-06-06
# start_range: 2015-03-30, doc_date: 2015-05-29, article_date: 2025-06-06
# start_range: 2015-03-30, doc_date: 2015-05-29, article_date: 2025-06-06
# start_range: 2015-03-30, doc_date: 2015-05-29, article_date: 2025-06-06
# start_range: 2015-03-30, doc_date: 2015-05-29, article_date: 2025-06-06
# start_range: 2015-03-30, doc_date: 2015-05-29, article_date: 2025-06-06
# start_range: 2015-03-30, doc_date: 2015-05-29, article_date: 2025-06-06
# start_range: 2015-03-30, doc_date: 2015-05-29, article_date: 2025-06-06
# start_range: 2015-03-30, doc_date: 2015-05-29, article_date: 2025-06-06
# 2015-04-02
# start_range: 2015-04-02, doc_date: 2015-06-01, article_date: 2025-06-06
# start_range: 2015-04-02, doc_date: 2015-06-01, article_date: 2025-06-06
# start_range: 2015-04-02, doc_date: 2015-06-01, article_date: 2025-06-06
# start_range: 2015-04-02, doc_date: 2015-06-01, article_date: 2025-06-06
# start_range: 2015-04-02, doc_date: 2015-06-01, article_date: 2025-06-06
# start_range: 2015-04-02, doc_date: 2015-06-01, article_date: 2025-06-06
# start_range: 2015-04-02, doc_date: 2015-06-01, article_date: 2025-06-06
# start_range: 2015-04-02, doc_date: 2015-06-01, article_date: 2025-06-06
# start_range: 2015-04-02, doc_date: 2015-06-01, article_date: 2025-06-06
# start_range: 2015-04-02, doc_date: 2015-06-01, article_date: 2025-06-06
# 2015-04-03
# start_range: 2015-04-03, doc_date: 2015-06-02, article_date: 2025-06-06
# start_range: 2015-04-03, doc_date: 2015-06-02, article_date: 2025-06-06
# start_range: 2015-04-03, doc_date: 2015-06-02, article_date: 2025-06-06
# start_range: 2015-04-03, doc_date: 2015-06-02, article_date: 2025-06-06
# start_range: 2015-04-03, doc_date: 2015-06-02, article_date: 2025-06-06
# start_range: 2015-04-03, doc_date: 2015-06-02, article_date: 2025-06-06
# start_range: 2015-04-03, doc_date: 2015-06-02, article_date: 2025-06-06
# start_range: 2015-04-03, doc_date: 2015-06-02, article_date: 2025-06-06
# start_range: 2015-04-03, doc_date: 2015-06-02, article_date: 2025-06-06
# start_range: 2015-04-03, doc_date: 2015-06-02, article_date: 2025-06-06
# 2015-04-04
# start_range: 2015-04-04, doc_date: 2015-06-03, article_date: 2025-06-06
# start_range: 2015-04-04, doc_date: 2015-06-03, article_date: 2025-06-06
# start_range: 2015-04-04, doc_date: 2015-06-03, article_date: 2025-06-06
# start_range: 2015-04-04, doc_date: 2015-06-03, article_date: 2025-06-06
# start_range: 2015-04-04, doc_date: 2015-06-03, article_date: 2025-06-06
# start_range: 2015-04-04, doc_date: 2015-06-03, article_date: 2025-06-06
# start_range: 2015-04-04, doc_date: 2015-06-03, article_date: 2025-06-06
# start_range: 2015-04-04, doc_date: 2015-06-03, article_date: 2025-06-06
# start_range: 2015-04-04, doc_date: 2015-06-03, article_date: 2025-06-06
# start_range: 2015-04-04, doc_date: 2015-06-03, article_date: 2025-06-06
# 2015-04-05
# start_range: 2015-04-05, doc_date: 2015-06-04, article_date: 2025-06-06
# start_range: 2015-04-05, doc_date: 2015-06-04, article_date: 2025-06-06
# start_range: 2015-04-05, doc_date: 2015-06-04, article_date: 2025-06-06
# start_range: 2015-04-05, doc_date: 2015-06-04, article_date: 2025-06-06
# start_range: 2015-04-05, doc_date: 2015-06-04, article_date: 2025-06-06
# start_range: 2015-04-05, doc_date: 2015-06-04, article_date: 2025-06-06
# start_range: 2015-04-05, doc_date: 2015-06-04, article_date: 2025-06-06
# start_range: 2015-04-05, doc_date: 2015-06-04, article_date: 2025-06-06
# start_range: 2015-04-05, doc_date: 2015-06-04, article_date: 2025-06-06
# start_range: 2015-04-05, doc_date: 2015-06-04, article_date: 2025-06-06
# 2015-04-06
# start_range: 2015-04-06, doc_date: 2015-06-05, article_date: 2025-06-06
# start_range: 2015-04-06, doc_date: 2015-06-05, article_date: 2025-06-06
# start_range: 2015-04-06, doc_date: 2015-06-05, article_date: 2025-06-06
# start_range: 2015-04-06, doc_date: 2015-06-05, article_date: 2025-06-06
# start_range: 2015-04-06, doc_date: 2015-06-05, article_date: 2025-06-06
# start_range: 2015-04-06, doc_date: 2015-06-05, article_date: 2025-06-06
# start_range: 2015-04-06, doc_date: 2015-06-05, article_date: 2025-06-06
# start_range: 2015-04-06, doc_date: 2015-06-05, article_date: 2025-06-06
# start_range: 2015-04-06, doc_date: 2015-06-05, article_date: 2025-06-06
# start_range: 2015-04-06, doc_date: 2015-06-05, article_date: 2025-06-06
# 2015-04-09
# start_range: 2015-04-09, doc_date: 2015-06-08, article_date: 2025-06-06
# start_range: 2015-04-09, doc_date: 2015-06-08, article_date: 2025-06-06
# start_range: 2015-04-09, doc_date: 2015-06-08, article_date: 2025-06-06
# start_range: 2015-04-09, doc_date: 2015-06-08, article_date: 2025-06-06
# start_range: 2015-04-09, doc_date: 2015-06-08, article_date: 2025-06-06
# start_range: 2015-04-09, doc_date: 2015-06-08, article_date: 2025-06-06
# start_range: 2015-04-09, doc_date: 2015-06-08, article_date: 2025-06-06
# start_range: 2015-04-09, doc_date: 2015-06-08, article_date: 2025-06-06
# start_range: 2015-04-09, doc_date: 2015-06-08, article_date: 2025-06-06
# start_range: 2015-04-09, doc_date: 2015-06-08, article_date: 2025-06-06
# 2015-04-10
# start_range: 2015-04-10, doc_date: 2015-06-09, article_date: 2025-06-06
# start_range: 2015-04-10, doc_date: 2015-06-09, article_date: 2025-06-06
# start_range: 2015-04-10, doc_date: 2015-06-09, article_date: 2025-06-06
# start_range: 2015-04-10, doc_date: 2015-06-09, article_date: 2025-06-06
# start_range: 2015-04-10, doc_date: 2015-06-09, article_date: 2025-06-06
# start_range: 2015-04-10, doc_date: 2015-06-09, article_date: 2025-06-06
# start_range: 2015-04-10, doc_date: 2015-06-09, article_date: 2025-06-06
# start_range: 2015-04-10, doc_date: 2015-06-09, article_date: 2025-06-06
# start_range: 2015-04-10, doc_date: 2015-06-09, article_date: 2025-06-06
# start_range: 2015-04-10, doc_date: 2015-06-09, article_date: 2025-06-06
# 2015-04-11
# start_range: 2015-04-11, doc_date: 2015-06-10, article_date: 2025-06-06
# start_range: 2015-04-11, doc_date: 2015-06-10, article_date: 2025-06-06
# start_range: 2015-04-11, doc_date: 2015-06-10, article_date: 2025-06-06
# start_range: 2015-04-11, doc_date: 2015-06-10, article_date: 2025-06-06
# start_range: 2015-04-11, doc_date: 2015-06-10, article_date: 2025-06-06
# start_range: 2015-04-11, doc_date: 2015-06-10, article_date: 2025-06-06
# start_range: 2015-04-11, doc_date: 2015-06-10, article_date: 2025-06-06
# start_range: 2015-04-11, doc_date: 2015-06-10, article_date: 2025-06-06
# start_range: 2015-04-11, doc_date: 2015-06-10, article_date: 2025-06-06
# start_range: 2015-04-11, doc_date: 2015-06-10, article_date: 2025-06-06
# 2015-04-12
# start_range: 2015-04-12, doc_date: 2015-06-11, article_date: 2025-06-06
# start_range: 2015-04-12, doc_date: 2015-06-11, article_date: 2025-06-06
# start_range: 2015-04-12, doc_date: 2015-06-11, article_date: 2025-06-06
# start_range: 2015-04-12, doc_date: 2015-06-11, article_date: 2025-06-06
# start_range: 2015-04-12, doc_date: 2015-06-11, article_date: 2025-06-06
# start_range: 2015-04-12, doc_date: 2015-06-11, article_date: 2025-06-06
# start_range: 2015-04-12, doc_date: 2015-06-11, article_date: 2025-06-06
# start_range: 2015-04-12, doc_date: 2015-06-11, article_date: 2025-06-06
# start_range: 2015-04-12, doc_date: 2015-06-11, article_date: 2025-06-06
# start_range: 2015-04-12, doc_date: 2015-06-11, article_date: 2025-06-06
# 2015-04-13
# start_range: 2015-04-13, doc_date: 2015-06-12, article_date: 2025-06-06
# start_range: 2015-04-13, doc_date: 2015-06-12, article_date: 2025-06-06
# start_range: 2015-04-13, doc_date: 2015-06-12, article_date: 2025-06-06
# start_range: 2015-04-13, doc_date: 2015-06-12, article_date: 2025-06-06
# start_range: 2015-04-13, doc_date: 2015-06-12, article_date: 2025-06-06
# start_range: 2015-04-13, doc_date: 2015-06-12, article_date: 2025-06-06
# start_range: 2015-04-13, doc_date: 2015-06-12, article_date: 2025-06-06
# start_range: 2015-04-13, doc_date: 2015-06-12, article_date: 2025-06-06
# start_range: 2015-04-13, doc_date: 2015-06-12, article_date: 2025-06-06
# start_range: 2015-04-13, doc_date: 2015-06-12, article_date: 2025-06-06
# 2015-04-16
# start_range: 2015-04-16, doc_date: 2015-06-15, article_date: 2025-06-06
# start_range: 2015-04-16, doc_date: 2015-06-15, article_date: 2025-06-06
# start_range: 2015-04-16, doc_date: 2015-06-15, article_date: 2025-06-06
# start_range: 2015-04-16, doc_date: 2015-06-15, article_date: 2025-06-06
# start_range: 2015-04-16, doc_date: 2015-06-15, article_date: 2025-06-06
# start_range: 2015-04-16, doc_date: 2015-06-15, article_date: 2025-06-06
# start_range: 2015-04-16, doc_date: 2015-06-15, article_date: 2025-06-06
# start_range: 2015-04-16, doc_date: 2015-06-15, article_date: 2025-06-06
# start_range: 2015-04-16, doc_date: 2015-06-15, article_date: 2025-06-06
# start_range: 2015-04-16, doc_date: 2015-06-15, article_date: 2025-06-06
# 2015-04-17
# start_range: 2015-04-17, doc_date: 2015-06-16, article_date: 2025-06-06
# start_range: 2015-04-17, doc_date: 2015-06-16, article_date: 2025-06-06
# start_range: 2015-04-17, doc_date: 2015-06-16, article_date: 2025-06-06
# start_range: 2015-04-17, doc_date: 2015-06-16, article_date: 2025-06-06
# start_range: 2015-04-17, doc_date: 2015-06-16, article_date: 2025-06-06
# start_range: 2015-04-17, doc_date: 2015-06-16, article_date: 2025-06-06
# start_range: 2015-04-17, doc_date: 2015-06-16, article_date: 2025-06-06
# start_range: 2015-04-17, doc_date: 2015-06-16, article_date: 2025-06-06
# start_range: 2015-04-17, doc_date: 2015-06-16, article_date: 2025-06-06
# start_range: 2015-04-17, doc_date: 2015-06-16, article_date: 2025-06-06
# 2015-04-18
# start_range: 2015-04-18, doc_date: 2015-06-17, article_date: 2025-06-06
# start_range: 2015-04-18, doc_date: 2015-06-17, article_date: 2025-06-06
# start_range: 2015-04-18, doc_date: 2015-06-17, article_date: 2025-06-06
# start_range: 2015-04-18, doc_date: 2015-06-17, article_date: 2025-06-06
# start_range: 2015-04-18, doc_date: 2015-06-17, article_date: 2025-06-06
# start_range: 2015-04-18, doc_date: 2015-06-17, article_date: 2025-06-06
# start_range: 2015-04-18, doc_date: 2015-06-17, article_date: 2025-06-06
# start_range: 2015-04-18, doc_date: 2015-06-17, article_date: 2025-06-06
# start_range: 2015-04-18, doc_date: 2015-06-17, article_date: 2025-06-06
# start_range: 2015-04-18, doc_date: 2015-06-17, article_date: 2025-06-06
# 2015-04-19
# start_range: 2015-04-19, doc_date: 2015-06-18, article_date: 2025-06-06
# start_range: 2015-04-19, doc_date: 2015-06-18, article_date: 2025-06-06
# start_range: 2015-04-19, doc_date: 2015-06-18, article_date: 2025-06-06
# start_range: 2015-04-19, doc_date: 2015-06-18, article_date: 2025-06-06
# start_range: 2015-04-19, doc_date: 2015-06-18, article_date: 2025-06-06
# start_range: 2015-04-19, doc_date: 2015-06-18, article_date: 2025-06-06
# start_range: 2015-04-19, doc_date: 2015-06-18, article_date: 2025-06-06
# start_range: 2015-04-19, doc_date: 2015-06-18, article_date: 2025-06-06
# start_range: 2015-04-19, doc_date: 2015-06-18, article_date: 2025-06-06
# start_range: 2015-04-19, doc_date: 2015-06-18, article_date: 2025-06-06
# 2015-04-20
# start_range: 2015-04-20, doc_date: 2015-06-19, article_date: 2025-06-06
# start_range: 2015-04-20, doc_date: 2015-06-19, article_date: 2025-06-06
# start_range: 2015-04-20, doc_date: 2015-06-19, article_date: 2025-06-06
# start_range: 2015-04-20, doc_date: 2015-06-19, article_date: 2025-06-06
# start_range: 2015-04-20, doc_date: 2015-06-19, article_date: 2025-06-06
# start_range: 2015-04-20, doc_date: 2015-06-19, article_date: 2025-06-06
# start_range: 2015-04-20, doc_date: 2015-06-19, article_date: 2025-06-06
# start_range: 2015-04-20, doc_date: 2015-06-19, article_date: 2025-06-06
# start_range: 2015-04-20, doc_date: 2015-06-19, article_date: 2025-06-06
# start_range: 2015-04-20, doc_date: 2015-06-19, article_date: 2025-06-06
# 2015-04-23
# start_range: 2015-04-23, doc_date: 2015-06-22, article_date: 2025-06-06
# start_range: 2015-04-23, doc_date: 2015-06-22, article_date: 2025-06-06
# start_range: 2015-04-23, doc_date: 2015-06-22, article_date: 2025-06-06
# start_range: 2015-04-23, doc_date: 2015-06-22, article_date: 2025-06-06
# start_range: 2015-04-23, doc_date: 2015-06-22, article_date: 2025-06-06
# start_range: 2015-04-23, doc_date: 2015-06-22, article_date: 2025-06-06
# start_range: 2015-04-23, doc_date: 2015-06-22, article_date: 2025-06-06
# start_range: 2015-04-23, doc_date: 2015-06-22, article_date: 2025-06-06
# start_range: 2015-04-23, doc_date: 2015-06-22, article_date: 2025-06-06
# start_range: 2015-04-23, doc_date: 2015-06-22, article_date: 2025-06-06
# 2015-04-24
# start_range: 2015-04-24, doc_date: 2015-06-23, article_date: 2025-06-06
# start_range: 2015-04-24, doc_date: 2015-06-23, article_date: 2025-06-06
# start_range: 2015-04-24, doc_date: 2015-06-23, article_date: 2025-06-06
# start_range: 2015-04-24, doc_date: 2015-06-23, article_date: 2025-06-06
# start_range: 2015-04-24, doc_date: 2015-06-23, article_date: 2025-06-06
# start_range: 2015-04-24, doc_date: 2015-06-23, article_date: 2025-06-06
# start_range: 2015-04-24, doc_date: 2015-06-23, article_date: 2025-06-06
# start_range: 2015-04-24, doc_date: 2015-06-23, article_date: 2025-06-06
# start_range: 2015-04-24, doc_date: 2015-06-23, article_date: 2025-06-06
# start_range: 2015-04-24, doc_date: 2015-06-23, article_date: 2025-06-06
# 2015-04-25
# start_range: 2015-04-25, doc_date: 2015-06-24, article_date: 2025-06-06
# start_range: 2015-04-25, doc_date: 2015-06-24, article_date: 2025-06-06
# start_range: 2015-04-25, doc_date: 2015-06-24, article_date: 2025-06-06
# start_range: 2015-04-25, doc_date: 2015-06-24, article_date: 2025-06-06
# start_range: 2015-04-25, doc_date: 2015-06-24, article_date: 2025-06-06
# start_range: 2015-04-25, doc_date: 2015-06-24, article_date: 2025-06-06
# start_range: 2015-04-25, doc_date: 2015-06-24, article_date: 2025-06-06
# start_range: 2015-04-25, doc_date: 2015-06-24, article_date: 2025-06-06
# start_range: 2015-04-25, doc_date: 2015-06-24, article_date: 2025-06-06
# start_range: 2015-04-25, doc_date: 2015-06-24, article_date: 2025-06-06
# 2015-04-26
# start_range: 2015-04-26, doc_date: 2015-06-25, article_date: 2025-06-06
# start_range: 2015-04-26, doc_date: 2015-06-25, article_date: 2025-06-06
# start_range: 2015-04-26, doc_date: 2015-06-25, article_date: 2025-06-06
# start_range: 2015-04-26, doc_date: 2015-06-25, article_date: 2025-06-06
# start_range: 2015-04-26, doc_date: 2015-06-25, article_date: 2025-06-06
# start_range: 2015-04-26, doc_date: 2015-06-25, article_date: 2025-06-06
# start_range: 2015-04-26, doc_date: 2015-06-25, article_date: 2025-06-06
# start_range: 2015-04-26, doc_date: 2015-06-25, article_date: 2025-06-06
# start_range: 2015-04-26, doc_date: 2015-06-25, article_date: 2025-06-06
# start_range: 2015-04-26, doc_date: 2015-06-25, article_date: 2025-06-06
# 2015-04-27
# start_range: 2015-04-27, doc_date: 2015-06-26, article_date: 2025-06-06
# start_range: 2015-04-27, doc_date: 2015-06-26, article_date: 2025-06-06
# start_range: 2015-04-27, doc_date: 2015-06-26, article_date: 2025-06-06
# start_range: 2015-04-27, doc_date: 2015-06-26, article_date: 2025-06-06
# start_range: 2015-04-27, doc_date: 2015-06-26, article_date: 2025-06-06
# start_range: 2015-04-27, doc_date: 2015-06-26, article_date: 2025-06-06
# start_range: 2015-04-27, doc_date: 2015-06-26, article_date: 2025-06-06
# start_range: 2015-04-27, doc_date: 2015-06-26, article_date: 2025-06-06
# start_range: 2015-04-27, doc_date: 2015-06-26, article_date: 2025-06-06
# start_range: 2015-04-27, doc_date: 2015-06-26, article_date: 2025-06-06
# 2015-04-30
# start_range: 2015-04-30, doc_date: 2015-06-29, article_date: 2025-06-06
# start_range: 2015-04-30, doc_date: 2015-06-29, article_date: 2025-06-06
# start_range: 2015-04-30, doc_date: 2015-06-29, article_date: 2025-06-06
# start_range: 2015-04-30, doc_date: 2015-06-29, article_date: 2025-06-06
# start_range: 2015-04-30, doc_date: 2015-06-29, article_date: 2025-06-06
# start_range: 2015-04-30, doc_date: 2015-06-29, article_date: 2025-06-06
# start_range: 2015-04-30, doc_date: 2015-06-29, article_date: 2025-06-06
# start_range: 2015-04-30, doc_date: 2015-06-29, article_date: 2025-06-06
# start_range: 2015-04-30, doc_date: 2015-06-29, article_date: 2025-06-06
# start_range: 2015-04-30, doc_date: 2015-06-29, article_date: 2025-06-06
# 2015-05-01
# start_range: 2015-05-01, doc_date: 2015-06-30, article_date: 2025-06-06
# start_range: 2015-05-01, doc_date: 2015-06-30, article_date: 2025-06-06
# start_range: 2015-05-01, doc_date: 2015-06-30, article_date: 2025-06-06
# start_range: 2015-05-01, doc_date: 2015-06-30, article_date: 2025-06-06
# start_range: 2015-05-01, doc_date: 2015-06-30, article_date: 2025-06-06
# start_range: 2015-05-01, doc_date: 2015-06-30, article_date: 2025-06-06
# start_range: 2015-05-01, doc_date: 2015-06-30, article_date: 2025-06-06
# start_range: 2015-05-01, doc_date: 2015-06-30, article_date: 2025-06-06
# start_range: 2015-05-01, doc_date: 2015-06-30, article_date: 2025-06-06
# start_range: 2015-05-01, doc_date: 2015-06-30, article_date: 2025-06-06
# 2015-05-02
# start_range: 2015-05-02, doc_date: 2015-07-01, article_date: 2025-06-06
# start_range: 2015-05-02, doc_date: 2015-07-01, article_date: 2025-06-06
# start_range: 2015-05-02, doc_date: 2015-07-01, article_date: 2025-06-06
# start_range: 2015-05-02, doc_date: 2015-07-01, article_date: 2025-06-06
# start_range: 2015-05-02, doc_date: 2015-07-01, article_date: 2025-06-06
# start_range: 2015-05-02, doc_date: 2015-07-01, article_date: 2025-06-06
# start_range: 2015-05-02, doc_date: 2015-07-01, article_date: 2025-06-06
# start_range: 2015-05-02, doc_date: 2015-07-01, article_date: 2025-06-06
# start_range: 2015-05-02, doc_date: 2015-07-01, article_date: 2025-06-06
# start_range: 2015-05-02, doc_date: 2015-07-01, article_date: 2025-06-06
# 2015-05-03
# start_range: 2015-05-03, doc_date: 2015-07-02, article_date: 2025-06-06
# start_range: 2015-05-03, doc_date: 2015-07-02, article_date: 2025-06-06
# start_range: 2015-05-03, doc_date: 2015-07-02, article_date: 2025-06-06
# start_range: 2015-05-03, doc_date: 2015-07-02, article_date: 2025-06-06
# start_range: 2015-05-03, doc_date: 2015-07-02, article_date: 2025-06-06
# start_range: 2015-05-03, doc_date: 2015-07-02, article_date: 2025-06-06
# start_range: 2015-05-03, doc_date: 2015-07-02, article_date: 2025-06-06
# start_range: 2015-05-03, doc_date: 2015-07-02, article_date: 2025-06-06
# start_range: 2015-05-03, doc_date: 2015-07-02, article_date: 2025-06-06
# start_range: 2015-05-03, doc_date: 2015-07-02, article_date: 2025-06-06
# 2015-05-07
# start_range: 2015-05-07, doc_date: 2015-07-06, article_date: 2025-06-06
# start_range: 2015-05-07, doc_date: 2015-07-06, article_date: 2025-06-06
# start_range: 2015-05-07, doc_date: 2015-07-06, article_date: 2025-06-06
# start_range: 2015-05-07, doc_date: 2015-07-06, article_date: 2025-06-06
# start_range: 2015-05-07, doc_date: 2015-07-06, article_date: 2025-06-06
# start_range: 2015-05-07, doc_date: 2015-07-06, article_date: 2025-06-06
# start_range: 2015-05-07, doc_date: 2015-07-06, article_date: 2025-06-06
# start_range: 2015-05-07, doc_date: 2015-07-06, article_date: 2025-06-06
# start_range: 2015-05-07, doc_date: 2015-07-06, article_date: 2025-06-06
# start_range: 2015-05-07, doc_date: 2015-07-06, article_date: 2025-06-06
# 2015-05-08
# start_range: 2015-05-08, doc_date: 2015-07-07, article_date: 2025-06-06
# start_range: 2015-05-08, doc_date: 2015-07-07, article_date: 2025-06-06
# start_range: 2015-05-08, doc_date: 2015-07-07, article_date: 2025-06-06
# start_range: 2015-05-08, doc_date: 2015-07-07, article_date: 2025-06-06
# start_range: 2015-05-08, doc_date: 2015-07-07, article_date: 2025-06-06
# start_range: 2015-05-08, doc_date: 2015-07-07, article_date: 2025-06-06
# start_range: 2015-05-08, doc_date: 2015-07-07, article_date: 2025-06-06
# start_range: 2015-05-08, doc_date: 2015-07-07, article_date: 2025-06-06
# start_range: 2015-05-08, doc_date: 2015-07-07, article_date: 2025-06-06
# start_range: 2015-05-08, doc_date: 2015-07-07, article_date: 2025-06-06
# 2015-05-09
# start_range: 2015-05-09, doc_date: 2015-07-08, article_date: 2025-06-06
# start_range: 2015-05-09, doc_date: 2015-07-08, article_date: 2025-06-06
# start_range: 2015-05-09, doc_date: 2015-07-08, article_date: 2025-06-06
# start_range: 2015-05-09, doc_date: 2015-07-08, article_date: 2025-06-06
# start_range: 2015-05-09, doc_date: 2015-07-08, article_date: 2025-06-06
# start_range: 2015-05-09, doc_date: 2015-07-08, article_date: 2025-06-06
# start_range: 2015-05-09, doc_date: 2015-07-08, article_date: 2025-06-06
# start_range: 2015-05-09, doc_date: 2015-07-08, article_date: 2025-06-06
# start_range: 2015-05-09, doc_date: 2015-07-08, article_date: 2025-06-06
# start_range: 2015-05-09, doc_date: 2015-07-08, article_date: 2025-06-06
# 2015-05-10
# start_range: 2015-05-10, doc_date: 2015-07-09, article_date: 2025-06-06
# start_range: 2015-05-10, doc_date: 2015-07-09, article_date: 2025-06-06
# start_range: 2015-05-10, doc_date: 2015-07-09, article_date: 2025-06-06
# start_range: 2015-05-10, doc_date: 2015-07-09, article_date: 2025-06-06
# start_range: 2015-05-10, doc_date: 2015-07-09, article_date: 2025-06-06
# start_range: 2015-05-10, doc_date: 2015-07-09, article_date: 2025-06-06
# start_range: 2015-05-10, doc_date: 2015-07-09, article_date: 2025-06-06
# start_range: 2015-05-10, doc_date: 2015-07-09, article_date: 2025-06-06
# start_range: 2015-05-10, doc_date: 2015-07-09, article_date: 2025-06-06
# start_range: 2015-05-10, doc_date: 2015-07-09, article_date: 2025-06-06
# 2015-05-11
# start_range: 2015-05-11, doc_date: 2015-07-10, article_date: 2025-06-06
# start_range: 2015-05-11, doc_date: 2015-07-10, article_date: 2025-06-06
# start_range: 2015-05-11, doc_date: 2015-07-10, article_date: 2025-06-06
# start_range: 2015-05-11, doc_date: 2015-07-10, article_date: 2025-06-06
# start_range: 2015-05-11, doc_date: 2015-07-10, article_date: 2025-06-06
# start_range: 2015-05-11, doc_date: 2015-07-10, article_date: 2025-06-06
# start_range: 2015-05-11, doc_date: 2015-07-10, article_date: 2025-06-06
# start_range: 2015-05-11, doc_date: 2015-07-10, article_date: 2025-06-06
# start_range: 2015-05-11, doc_date: 2015-07-10, article_date: 2025-06-06
# start_range: 2015-05-11, doc_date: 2015-07-10, article_date: 2025-06-06
# 2015-05-14
# start_range: 2015-05-14, doc_date: 2015-07-13, article_date: 2025-06-06
# start_range: 2015-05-14, doc_date: 2015-07-13, article_date: 2025-06-06
# start_range: 2015-05-14, doc_date: 2015-07-13, article_date: 2025-06-06
# start_range: 2015-05-14, doc_date: 2015-07-13, article_date: 2025-06-06
# start_range: 2015-05-14, doc_date: 2015-07-13, article_date: 2025-06-06
# start_range: 2015-05-14, doc_date: 2015-07-13, article_date: 2025-06-06
# start_range: 2015-05-14, doc_date: 2015-07-13, article_date: 2025-06-06
# start_range: 2015-05-14, doc_date: 2015-07-13, article_date: 2025-06-06
# start_range: 2015-05-14, doc_date: 2015-07-13, article_date: 2025-06-06
# start_range: 2015-05-14, doc_date: 2015-07-13, article_date: 2025-06-06
# 2015-05-15
# start_range: 2015-05-15, doc_date: 2015-07-14, article_date: 2025-06-06
# start_range: 2015-05-15, doc_date: 2015-07-14, article_date: 2025-06-06
# start_range: 2015-05-15, doc_date: 2015-07-14, article_date: 2025-06-06
# start_range: 2015-05-15, doc_date: 2015-07-14, article_date: 2025-06-06
# start_range: 2015-05-15, doc_date: 2015-07-14, article_date: 2025-06-06
# start_range: 2015-05-15, doc_date: 2015-07-14, article_date: 2025-06-06
# start_range: 2015-05-15, doc_date: 2015-07-14, article_date: 2025-06-06
# start_range: 2015-05-15, doc_date: 2015-07-14, article_date: 2025-06-06
# start_range: 2015-05-15, doc_date: 2015-07-14, article_date: 2025-06-06
# start_range: 2015-05-15, doc_date: 2015-07-14, article_date: 2025-06-06
# 2015-05-16
# start_range: 2015-05-16, doc_date: 2015-07-15, article_date: 2025-06-06
# start_range: 2015-05-16, doc_date: 2015-07-15, article_date: 2025-06-06
# start_range: 2015-05-16, doc_date: 2015-07-15, article_date: 2025-06-06
# start_range: 2015-05-16, doc_date: 2015-07-15, article_date: 2025-06-06
# start_range: 2015-05-16, doc_date: 2015-07-15, article_date: 2025-06-06
# start_range: 2015-05-16, doc_date: 2015-07-15, article_date: 2025-06-06
# start_range: 2015-05-16, doc_date: 2015-07-15, article_date: 2025-06-06
# start_range: 2015-05-16, doc_date: 2015-07-15, article_date: 2025-06-06
# start_range: 2015-05-16, doc_date: 2015-07-15, article_date: 2025-06-06
# start_range: 2015-05-16, doc_date: 2015-07-15, article_date: 2025-06-06
# 2015-05-17
# start_range: 2015-05-17, doc_date: 2015-07-16, article_date: 2025-06-06
# start_range: 2015-05-17, doc_date: 2015-07-16, article_date: 2025-06-06
# start_range: 2015-05-17, doc_date: 2015-07-16, article_date: 2025-06-06
# start_range: 2015-05-17, doc_date: 2015-07-16, article_date: 2025-06-06
# start_range: 2015-05-17, doc_date: 2015-07-16, article_date: 2025-06-06
# start_range: 2015-05-17, doc_date: 2015-07-16, article_date: 2025-06-06
# start_range: 2015-05-17, doc_date: 2015-07-16, article_date: 2025-06-06
# start_range: 2015-05-17, doc_date: 2015-07-16, article_date: 2025-06-06
# start_range: 2015-05-17, doc_date: 2015-07-16, article_date: 2025-06-06
# start_range: 2015-05-17, doc_date: 2015-07-16, article_date: 2025-06-06
# 2015-05-18
# start_range: 2015-05-18, doc_date: 2015-07-17, article_date: 2025-06-06
# start_range: 2015-05-18, doc_date: 2015-07-17, article_date: 2025-06-06
# start_range: 2015-05-18, doc_date: 2015-07-17, article_date: 2025-06-06
# start_range: 2015-05-18, doc_date: 2015-07-17, article_date: 2025-06-06
# start_range: 2015-05-18, doc_date: 2015-07-17, article_date: 2025-06-06
# start_range: 2015-05-18, doc_date: 2015-07-17, article_date: 2025-06-06
# start_range: 2015-05-18, doc_date: 2015-07-17, article_date: 2025-06-06
# start_range: 2015-05-18, doc_date: 2015-07-17, article_date: 2025-06-06
# start_range: 2015-05-18, doc_date: 2015-07-17, article_date: 2025-06-06
# start_range: 2015-05-18, doc_date: 2015-07-17, article_date: 2025-06-06
# 2015-05-21
# start_range: 2015-05-21, doc_date: 2015-07-20, article_date: 2025-06-06
# start_range: 2015-05-21, doc_date: 2015-07-20, article_date: 2025-06-06
# start_range: 2015-05-21, doc_date: 2015-07-20, article_date: 2025-06-06
# start_range: 2015-05-21, doc_date: 2015-07-20, article_date: 2025-06-06
# start_range: 2015-05-21, doc_date: 2015-07-20, article_date: 2025-06-06
# start_range: 2015-05-21, doc_date: 2015-07-20, article_date: 2025-06-06
# start_range: 2015-05-21, doc_date: 2015-07-20, article_date: 2025-06-06
# start_range: 2015-05-21, doc_date: 2015-07-20, article_date: 2025-06-06
# start_range: 2015-05-21, doc_date: 2015-07-20, article_date: 2025-06-06
# start_range: 2015-05-21, doc_date: 2015-07-20, article_date: 2025-06-06
# 2015-05-22
# start_range: 2015-05-22, doc_date: 2015-07-21, article_date: 2025-06-06
# start_range: 2015-05-22, doc_date: 2015-07-21, article_date: 2025-06-06
# start_range: 2015-05-22, doc_date: 2015-07-21, article_date: 2025-06-06
# start_range: 2015-05-22, doc_date: 2015-07-21, article_date: 2025-06-06
# start_range: 2015-05-22, doc_date: 2015-07-21, article_date: 2025-06-06
# start_range: 2015-05-22, doc_date: 2015-07-21, article_date: 2025-06-06
# start_range: 2015-05-22, doc_date: 2015-07-21, article_date: 2025-06-06
# start_range: 2015-05-22, doc_date: 2015-07-21, article_date: 2025-06-06
# start_range: 2015-05-22, doc_date: 2015-07-21, article_date: 2025-06-06
# start_range: 2015-05-22, doc_date: 2015-07-21, article_date: 2025-06-06
# 2015-05-23
# start_range: 2015-05-23, doc_date: 2015-07-22, article_date: 2025-06-06
# start_range: 2015-05-23, doc_date: 2015-07-22, article_date: 2025-06-06
# start_range: 2015-05-23, doc_date: 2015-07-22, article_date: 2025-06-06
# start_range: 2015-05-23, doc_date: 2015-07-22, article_date: 2025-06-06
# start_range: 2015-05-23, doc_date: 2015-07-22, article_date: 2025-06-06
# start_range: 2015-05-23, doc_date: 2015-07-22, article_date: 2025-06-06
# start_range: 2015-05-23, doc_date: 2015-07-22, article_date: 2025-06-06
# start_range: 2015-05-23, doc_date: 2015-07-22, article_date: 2025-06-06
# start_range: 2015-05-23, doc_date: 2015-07-22, article_date: 2025-06-06
# start_range: 2015-05-23, doc_date: 2015-07-22, article_date: 2025-06-06
# 2015-05-24
# start_range: 2015-05-24, doc_date: 2015-07-23, article_date: 2025-06-06
# start_range: 2015-05-24, doc_date: 2015-07-23, article_date: 2025-06-06
# start_range: 2015-05-24, doc_date: 2015-07-23, article_date: 2025-06-06
# start_range: 2015-05-24, doc_date: 2015-07-23, article_date: 2025-06-06
# start_range: 2015-05-24, doc_date: 2015-07-23, article_date: 2025-06-06
# start_range: 2015-05-24, doc_date: 2015-07-23, article_date: 2025-06-06
# start_range: 2015-05-24, doc_date: 2015-07-23, article_date: 2025-06-06
# start_range: 2015-05-24, doc_date: 2015-07-23, article_date: 2025-06-06
# start_range: 2015-05-24, doc_date: 2015-07-23, article_date: 2025-06-06
# start_range: 2015-05-24, doc_date: 2015-07-23, article_date: 2025-06-06
# 2015-05-25
# start_range: 2015-05-25, doc_date: 2015-07-24, article_date: 2025-06-06
# start_range: 2015-05-25, doc_date: 2015-07-24, article_date: 2025-06-06
# start_range: 2015-05-25, doc_date: 2015-07-24, article_date: 2025-06-06
# start_range: 2015-05-25, doc_date: 2015-07-24, article_date: 2025-06-06
# start_range: 2015-05-25, doc_date: 2015-07-24, article_date: 2025-06-06
# start_range: 2015-05-25, doc_date: 2015-07-24, article_date: 2025-06-06
# start_range: 2015-05-25, doc_date: 2015-07-24, article_date: 2025-06-06
# start_range: 2015-05-25, doc_date: 2015-07-24, article_date: 2025-06-06
# start_range: 2015-05-25, doc_date: 2015-07-24, article_date: 2025-06-06
# start_range: 2015-05-25, doc_date: 2015-07-24, article_date: 2025-06-06
# 2015-05-28
# start_range: 2015-05-28, doc_date: 2015-07-27, article_date: 2025-06-06
# start_range: 2015-05-28, doc_date: 2015-07-27, article_date: 2025-06-06
# start_range: 2015-05-28, doc_date: 2015-07-27, article_date: 2025-06-06
# start_range: 2015-05-28, doc_date: 2015-07-27, article_date: 2025-06-06
# start_range: 2015-05-28, doc_date: 2015-07-27, article_date: 2025-06-06
# start_range: 2015-05-28, doc_date: 2015-07-27, article_date: 2025-06-06
# start_range: 2015-05-28, doc_date: 2015-07-27, article_date: 2025-06-06
# start_range: 2015-05-28, doc_date: 2015-07-27, article_date: 2025-06-06
# start_range: 2015-05-28, doc_date: 2015-07-27, article_date: 2025-06-06
# start_range: 2015-05-28, doc_date: 2015-07-27, article_date: 2025-06-06
# 2015-05-29
# start_range: 2015-05-29, doc_date: 2015-07-28, article_date: 2025-06-06
# start_range: 2015-05-29, doc_date: 2015-07-28, article_date: 2025-06-06
# start_range: 2015-05-29, doc_date: 2015-07-28, article_date: 2025-06-06
# start_range: 2015-05-29, doc_date: 2015-07-28, article_date: 2025-06-06
# start_range: 2015-05-29, doc_date: 2015-07-28, article_date: 2025-06-06
# start_range: 2015-05-29, doc_date: 2015-07-28, article_date: 2025-06-06
# start_range: 2015-05-29, doc_date: 2015-07-28, article_date: 2025-06-06
# start_range: 2015-05-29, doc_date: 2015-07-28, article_date: 2025-06-06
# start_range: 2015-05-29, doc_date: 2015-07-28, article_date: 2025-06-06
# start_range: 2015-05-29, doc_date: 2015-07-28, article_date: 2025-06-06
# 2015-05-30
# start_range: 2015-05-30, doc_date: 2015-07-29, article_date: 2025-06-06
# start_range: 2015-05-30, doc_date: 2015-07-29, article_date: 2025-06-06
# start_range: 2015-05-30, doc_date: 2015-07-29, article_date: 2025-06-06
# start_range: 2015-05-30, doc_date: 2015-07-29, article_date: 2025-06-06
# start_range: 2015-05-30, doc_date: 2015-07-29, article_date: 2025-06-06
# start_range: 2015-05-30, doc_date: 2015-07-29, article_date: 2025-06-06
# start_range: 2015-05-30, doc_date: 2015-07-29, article_date: 2025-06-06
# start_range: 2015-05-30, doc_date: 2015-07-29, article_date: 2025-06-06
# start_range: 2015-05-30, doc_date: 2015-07-29, article_date: 2025-06-06
# start_range: 2015-05-30, doc_date: 2015-07-29, article_date: 2025-06-06
# 2015-05-31
# start_range: 2015-05-31, doc_date: 2015-07-30, article_date: 2025-06-06
# start_range: 2015-05-31, doc_date: 2015-07-30, article_date: 2025-06-06
# start_range: 2015-05-31, doc_date: 2015-07-30, article_date: 2025-06-06
# start_range: 2015-05-31, doc_date: 2015-07-30, article_date: 2025-06-06
# start_range: 2015-05-31, doc_date: 2015-07-30, article_date: 2025-06-06
# start_range: 2015-05-31, doc_date: 2015-07-30, article_date: 2025-06-06
# start_range: 2015-05-31, doc_date: 2015-07-30, article_date: 2025-06-06
# start_range: 2015-05-31, doc_date: 2015-07-30, article_date: 2025-06-06
# start_range: 2015-05-31, doc_date: 2015-07-30, article_date: 2025-06-06
# start_range: 2015-05-31, doc_date: 2015-07-30, article_date: 2025-06-06
# 2015-06-01
# start_range: 2015-06-01, doc_date: 2015-07-31, article_date: 2025-06-06
# start_range: 2015-06-01, doc_date: 2015-07-31, article_date: 2025-06-06
# start_range: 2015-06-01, doc_date: 2015-07-31, article_date: 2025-06-06
# start_range: 2015-06-01, doc_date: 2015-07-31, article_date: 2025-06-06
# start_range: 2015-06-01, doc_date: 2015-07-31, article_date: 2025-06-06
# start_range: 2015-06-01, doc_date: 2015-07-31, article_date: 2025-06-06
# start_range: 2015-06-01, doc_date: 2015-07-31, article_date: 2025-06-06
# start_range: 2015-06-01, doc_date: 2015-07-31, article_date: 2025-06-06
# start_range: 2015-06-01, doc_date: 2015-07-31, article_date: 2025-06-06
# start_range: 2015-06-01, doc_date: 2015-07-31, article_date: 2025-06-06
# 2015-06-04
# start_range: 2015-06-04, doc_date: 2015-08-03, article_date: 2025-06-06
# start_range: 2015-06-04, doc_date: 2015-08-03, article_date: 2025-06-06
# start_range: 2015-06-04, doc_date: 2015-08-03, article_date: 2025-06-06
# start_range: 2015-06-04, doc_date: 2015-08-03, article_date: 2025-06-06
# start_range: 2015-06-04, doc_date: 2015-08-03, article_date: 2025-06-06
# start_range: 2015-06-04, doc_date: 2015-08-03, article_date: 2025-06-06
# start_range: 2015-06-04, doc_date: 2015-08-03, article_date: 2025-06-06
# start_range: 2015-06-04, doc_date: 2015-08-03, article_date: 2025-06-06
# start_range: 2015-06-04, doc_date: 2015-08-03, article_date: 2025-06-06
# start_range: 2015-06-04, doc_date: 2015-08-03, article_date: 2025-06-06
# 2015-06-05
# start_range: 2015-06-05, doc_date: 2015-08-04, article_date: 2025-06-06
# start_range: 2015-06-05, doc_date: 2015-08-04, article_date: 2025-06-06
# start_range: 2015-06-05, doc_date: 2015-08-04, article_date: 2025-06-06
# start_range: 2015-06-05, doc_date: 2015-08-04, article_date: 2025-06-06
# start_range: 2015-06-05, doc_date: 2015-08-04, article_date: 2025-06-06
# start_range: 2015-06-05, doc_date: 2015-08-04, article_date: 2025-06-06
# start_range: 2015-06-05, doc_date: 2015-08-04, article_date: 2025-06-06
# start_range: 2015-06-05, doc_date: 2015-08-04, article_date: 2025-06-06
# start_range: 2015-06-05, doc_date: 2015-08-04, article_date: 2025-06-06
# start_range: 2015-06-05, doc_date: 2015-08-04, article_date: 2025-06-06
# 2015-06-06
# start_range: 2015-06-06, doc_date: 2015-08-05, article_date: 2025-06-06
# start_range: 2015-06-06, doc_date: 2015-08-05, article_date: 2025-06-06
# start_range: 2015-06-06, doc_date: 2015-08-05, article_date: 2025-06-06
# start_range: 2015-06-06, doc_date: 2015-08-05, article_date: 2025-06-06
# start_range: 2015-06-06, doc_date: 2015-08-05, article_date: 2025-06-06
# start_range: 2015-06-06, doc_date: 2015-08-05, article_date: 2025-06-06
# start_range: 2015-06-06, doc_date: 2015-08-05, article_date: 2025-06-06
# start_range: 2015-06-06, doc_date: 2015-08-05, article_date: 2025-06-06
# start_range: 2015-06-06, doc_date: 2015-08-05, article_date: 2025-06-06
# start_range: 2015-06-06, doc_date: 2015-08-05, article_date: 2025-06-06
# 2015-06-07
# start_range: 2015-06-07, doc_date: 2015-08-06, article_date: 2025-06-06
# start_range: 2015-06-07, doc_date: 2015-08-06, article_date: 2025-06-06
# start_range: 2015-06-07, doc_date: 2015-08-06, article_date: 2025-06-06
# start_range: 2015-06-07, doc_date: 2015-08-06, article_date: 2025-06-06
# start_range: 2015-06-07, doc_date: 2015-08-06, article_date: 2025-06-06
# start_range: 2015-06-07, doc_date: 2015-08-06, article_date: 2025-06-06
# start_range: 2015-06-07, doc_date: 2015-08-06, article_date: 2025-06-06
# start_range: 2015-06-07, doc_date: 2015-08-06, article_date: 2025-06-06
# start_range: 2015-06-07, doc_date: 2015-08-06, article_date: 2025-06-06
# start_range: 2015-06-07, doc_date: 2015-08-06, article_date: 2025-06-06
# 2015-06-08
# start_range: 2015-06-08, doc_date: 2015-08-07, article_date: 2025-06-06
# start_range: 2015-06-08, doc_date: 2015-08-07, article_date: 2025-06-06
# start_range: 2015-06-08, doc_date: 2015-08-07, article_date: 2025-06-06
# start_range: 2015-06-08, doc_date: 2015-08-07, article_date: 2025-06-06
# start_range: 2015-06-08, doc_date: 2015-08-07, article_date: 2025-06-06
# start_range: 2015-06-08, doc_date: 2015-08-07, article_date: 2025-06-06
# start_range: 2015-06-08, doc_date: 2015-08-07, article_date: 2025-06-06
# start_range: 2015-06-08, doc_date: 2015-08-07, article_date: 2025-06-06
# start_range: 2015-06-08, doc_date: 2015-08-07, article_date: 2025-06-06
# start_range: 2015-06-08, doc_date: 2015-08-07, article_date: 2025-06-06
# 2015-06-11
# start_range: 2015-06-11, doc_date: 2015-08-10, article_date: 2025-06-06
# start_range: 2015-06-11, doc_date: 2015-08-10, article_date: 2025-06-06
# start_range: 2015-06-11, doc_date: 2015-08-10, article_date: 2025-06-06
# start_range: 2015-06-11, doc_date: 2015-08-10, article_date: 2025-06-06
# start_range: 2015-06-11, doc_date: 2015-08-10, article_date: 2025-06-06
# start_range: 2015-06-11, doc_date: 2015-08-10, article_date: 2025-06-06
# start_range: 2015-06-11, doc_date: 2015-08-10, article_date: 2025-06-06
# start_range: 2015-06-11, doc_date: 2015-08-10, article_date: 2025-06-06
# start_range: 2015-06-11, doc_date: 2015-08-10, article_date: 2025-06-06
# start_range: 2015-06-11, doc_date: 2015-08-10, article_date: 2025-06-06
# 2015-06-12
# start_range: 2015-06-12, doc_date: 2015-08-11, article_date: 2025-06-06
# start_range: 2015-06-12, doc_date: 2015-08-11, article_date: 2025-06-06
# start_range: 2015-06-12, doc_date: 2015-08-11, article_date: 2025-06-06
# start_range: 2015-06-12, doc_date: 2015-08-11, article_date: 2025-06-06
# start_range: 2015-06-12, doc_date: 2015-08-11, article_date: 2025-06-06
# start_range: 2015-06-12, doc_date: 2015-08-11, article_date: 2025-06-06
# start_range: 2015-06-12, doc_date: 2015-08-11, article_date: 2025-06-06
# start_range: 2015-06-12, doc_date: 2015-08-11, article_date: 2025-06-06
# start_range: 2015-06-12, doc_date: 2015-08-11, article_date: 2025-06-06
# start_range: 2015-06-12, doc_date: 2015-08-11, article_date: 2025-06-06
# 2015-06-13
# start_range: 2015-06-13, doc_date: 2015-08-12, article_date: 2025-06-06
# start_range: 2015-06-13, doc_date: 2015-08-12, article_date: 2025-06-06
# start_range: 2015-06-13, doc_date: 2015-08-12, article_date: 2025-06-06
# start_range: 2015-06-13, doc_date: 2015-08-12, article_date: 2025-06-06
# start_range: 2015-06-13, doc_date: 2015-08-12, article_date: 2025-06-06
# start_range: 2015-06-13, doc_date: 2015-08-12, article_date: 2025-06-06
# start_range: 2015-06-13, doc_date: 2015-08-12, article_date: 2025-06-06
# start_range: 2015-06-13, doc_date: 2015-08-12, article_date: 2025-06-06
# start_range: 2015-06-13, doc_date: 2015-08-12, article_date: 2025-06-06
# start_range: 2015-06-13, doc_date: 2015-08-12, article_date: 2025-06-06
# 2015-06-14
# start_range: 2015-06-14, doc_date: 2015-08-13, article_date: 2025-06-06
# start_range: 2015-06-14, doc_date: 2015-08-13, article_date: 2025-06-06
# start_range: 2015-06-14, doc_date: 2015-08-13, article_date: 2025-06-06
# start_range: 2015-06-14, doc_date: 2015-08-13, article_date: 2025-06-06
# start_range: 2015-06-14, doc_date: 2015-08-13, article_date: 2025-06-06
# start_range: 2015-06-14, doc_date: 2015-08-13, article_date: 2025-06-06
# start_range: 2015-06-14, doc_date: 2015-08-13, article_date: 2025-06-06
# start_range: 2015-06-14, doc_date: 2015-08-13, article_date: 2025-06-06
# start_range: 2015-06-14, doc_date: 2015-08-13, article_date: 2025-06-06
# start_range: 2015-06-14, doc_date: 2015-08-13, article_date: 2025-06-06
# 2015-06-15
# start_range: 2015-06-15, doc_date: 2015-08-14, article_date: 2025-06-06
# start_range: 2015-06-15, doc_date: 2015-08-14, article_date: 2025-06-06
# start_range: 2015-06-15, doc_date: 2015-08-14, article_date: 2025-06-06
# start_range: 2015-06-15, doc_date: 2015-08-14, article_date: 2025-06-06
# start_range: 2015-06-15, doc_date: 2015-08-14, article_date: 2025-06-06
# start_range: 2015-06-15, doc_date: 2015-08-14, article_date: 2025-06-06
# start_range: 2015-06-15, doc_date: 2015-08-14, article_date: 2025-06-06
# start_range: 2015-06-15, doc_date: 2015-08-14, article_date: 2025-06-06
# start_range: 2015-06-15, doc_date: 2015-08-14, article_date: 2025-06-06
# start_range: 2015-06-15, doc_date: 2015-08-14, article_date: 2025-06-06
# 2015-06-18
# start_range: 2015-06-18, doc_date: 2015-08-17, article_date: 2025-06-06
# start_range: 2015-06-18, doc_date: 2015-08-17, article_date: 2025-06-06
# start_range: 2015-06-18, doc_date: 2015-08-17, article_date: 2025-06-06
# start_range: 2015-06-18, doc_date: 2015-08-17, article_date: 2025-06-06
# start_range: 2015-06-18, doc_date: 2015-08-17, article_date: 2025-06-06
# start_range: 2015-06-18, doc_date: 2015-08-17, article_date: 2025-06-06
# start_range: 2015-06-18, doc_date: 2015-08-17, article_date: 2025-06-06
# start_range: 2015-06-18, doc_date: 2015-08-17, article_date: 2025-06-06
# start_range: 2015-06-18, doc_date: 2015-08-17, article_date: 2025-06-06
# start_range: 2015-06-18, doc_date: 2015-08-17, article_date: 2025-06-06
# 2015-06-19
# start_range: 2015-06-19, doc_date: 2015-08-18, article_date: 2025-06-06
# start_range: 2015-06-19, doc_date: 2015-08-18, article_date: 2025-06-06
# start_range: 2015-06-19, doc_date: 2015-08-18, article_date: 2025-06-06
# start_range: 2015-06-19, doc_date: 2015-08-18, article_date: 2025-06-06
# start_range: 2015-06-19, doc_date: 2015-08-18, article_date: 2025-06-06
# start_range: 2015-06-19, doc_date: 2015-08-18, article_date: 2025-06-06
# start_range: 2015-06-19, doc_date: 2015-08-18, article_date: 2025-06-06
# start_range: 2015-06-19, doc_date: 2015-08-18, article_date: 2025-06-06
# start_range: 2015-06-19, doc_date: 2015-08-18, article_date: 2025-06-06
# start_range: 2015-06-19, doc_date: 2015-08-18, article_date: 2025-06-06
# 2015-06-20
# start_range: 2015-06-20, doc_date: 2015-08-19, article_date: 2025-06-06
# start_range: 2015-06-20, doc_date: 2015-08-19, article_date: 2025-06-06
# start_range: 2015-06-20, doc_date: 2015-08-19, article_date: 2025-06-06
# start_range: 2015-06-20, doc_date: 2015-08-19, article_date: 2025-06-06
# start_range: 2015-06-20, doc_date: 2015-08-19, article_date: 2025-06-06
# start_range: 2015-06-20, doc_date: 2015-08-19, article_date: 2025-06-06
# start_range: 2015-06-20, doc_date: 2015-08-19, article_date: 2025-06-06
# start_range: 2015-06-20, doc_date: 2015-08-19, article_date: 2025-06-06
# start_range: 2015-06-20, doc_date: 2015-08-19, article_date: 2025-06-06
# start_range: 2015-06-20, doc_date: 2015-08-19, article_date: 2025-06-06
# 2015-06-21
# start_range: 2015-06-21, doc_date: 2015-08-20, article_date: 2025-06-06
# start_range: 2015-06-21, doc_date: 2015-08-20, article_date: 2025-06-06
# start_range: 2015-06-21, doc_date: 2015-08-20, article_date: 2025-06-06
# start_range: 2015-06-21, doc_date: 2015-08-20, article_date: 2025-06-06
# start_range: 2015-06-21, doc_date: 2015-08-20, article_date: 2025-06-06
# start_range: 2015-06-21, doc_date: 2015-08-20, article_date: 2025-06-06
# start_range: 2015-06-21, doc_date: 2015-08-20, article_date: 2025-06-06
# start_range: 2015-06-21, doc_date: 2015-08-20, article_date: 2025-06-06
# start_range: 2015-06-21, doc_date: 2015-08-20, article_date: 2025-06-06
# start_range: 2015-06-21, doc_date: 2015-08-20, article_date: 2025-06-06
# 2015-06-22
# start_range: 2015-06-22, doc_date: 2015-08-21, article_date: 2025-06-06
# start_range: 2015-06-22, doc_date: 2015-08-21, article_date: 2025-06-06
# start_range: 2015-06-22, doc_date: 2015-08-21, article_date: 2025-06-06
# start_range: 2015-06-22, doc_date: 2015-08-21, article_date: 2025-06-06
# start_range: 2015-06-22, doc_date: 2015-08-21, article_date: 2025-06-06
# start_range: 2015-06-22, doc_date: 2015-08-21, article_date: 2025-06-06
# start_range: 2015-06-22, doc_date: 2015-08-21, article_date: 2025-06-06
# start_range: 2015-06-22, doc_date: 2015-08-21, article_date: 2025-06-06
# start_range: 2015-06-22, doc_date: 2015-08-21, article_date: 2025-06-06
# start_range: 2015-06-22, doc_date: 2015-08-21, article_date: 2025-06-06
# 2015-06-25
# start_range: 2015-06-25, doc_date: 2015-08-24, article_date: 2025-06-06
# start_range: 2015-06-25, doc_date: 2015-08-24, article_date: 2025-06-06
# start_range: 2015-06-25, doc_date: 2015-08-24, article_date: 2025-06-06
# start_range: 2015-06-25, doc_date: 2015-08-24, article_date: 2025-06-06
# start_range: 2015-06-25, doc_date: 2015-08-24, article_date: 2025-06-06
# start_range: 2015-06-25, doc_date: 2015-08-24, article_date: 2025-06-06
# start_range: 2015-06-25, doc_date: 2015-08-24, article_date: 2025-06-06
# start_range: 2015-06-25, doc_date: 2015-08-24, article_date: 2025-06-06
# start_range: 2015-06-25, doc_date: 2015-08-24, article_date: 2025-06-06
# start_range: 2015-06-25, doc_date: 2015-08-24, article_date: 2025-06-06
# 2015-06-26
# start_range: 2015-06-26, doc_date: 2015-08-25, article_date: 2025-06-06
# start_range: 2015-06-26, doc_date: 2015-08-25, article_date: 2025-06-06
# start_range: 2015-06-26, doc_date: 2015-08-25, article_date: 2025-06-06
# start_range: 2015-06-26, doc_date: 2015-08-25, article_date: 2025-06-06
# start_range: 2015-06-26, doc_date: 2015-08-25, article_date: 2025-06-06
# start_range: 2015-06-26, doc_date: 2015-08-25, article_date: 2025-06-06
# start_range: 2015-06-26, doc_date: 2015-08-25, article_date: 2025-06-06
# start_range: 2015-06-26, doc_date: 2015-08-25, article_date: 2025-06-06
# start_range: 2015-06-26, doc_date: 2015-08-25, article_date: 2025-06-06
# start_range: 2015-06-26, doc_date: 2015-08-25, article_date: 2025-06-06
# 2015-06-27
# start_range: 2015-06-27, doc_date: 2015-08-26, article_date: 2025-06-06
# start_range: 2015-06-27, doc_date: 2015-08-26, article_date: 2025-06-06
# start_range: 2015-06-27, doc_date: 2015-08-26, article_date: 2025-06-06
# start_range: 2015-06-27, doc_date: 2015-08-26, article_date: 2025-06-06
# start_range: 2015-06-27, doc_date: 2015-08-26, article_date: 2025-06-06
# start_range: 2015-06-27, doc_date: 2015-08-26, article_date: 2025-06-06
# start_range: 2015-06-27, doc_date: 2015-08-26, article_date: 2025-06-06
# start_range: 2015-06-27, doc_date: 2015-08-26, article_date: 2025-06-06
# start_range: 2015-06-27, doc_date: 2015-08-26, article_date: 2025-06-06
# start_range: 2015-06-27, doc_date: 2015-08-26, article_date: 2025-06-06
# 2015-06-28
# start_range: 2015-06-28, doc_date: 2015-08-27, article_date: 2025-06-06
# start_range: 2015-06-28, doc_date: 2015-08-27, article_date: 2025-06-06
# start_range: 2015-06-28, doc_date: 2015-08-27, article_date: 2025-06-06
# start_range: 2015-06-28, doc_date: 2015-08-27, article_date: 2025-06-06
# start_range: 2015-06-28, doc_date: 2015-08-27, article_date: 2025-06-06
# start_range: 2015-06-28, doc_date: 2015-08-27, article_date: 2025-06-06
# start_range: 2015-06-28, doc_date: 2015-08-27, article_date: 2025-06-06
# start_range: 2015-06-28, doc_date: 2015-08-27, article_date: 2025-06-06
# start_range: 2015-06-28, doc_date: 2015-08-27, article_date: 2025-06-06
# start_range: 2015-06-28, doc_date: 2015-08-27, article_date: 2025-06-06
# 2015-06-29
# start_range: 2015-06-29, doc_date: 2015-08-28, article_date: 2025-06-06
# start_range: 2015-06-29, doc_date: 2015-08-28, article_date: 2025-06-06
# start_range: 2015-06-29, doc_date: 2015-08-28, article_date: 2025-06-06
# start_range: 2015-06-29, doc_date: 2015-08-28, article_date: 2025-06-06
# start_range: 2015-06-29, doc_date: 2015-08-28, article_date: 2025-06-06
# start_range: 2015-06-29, doc_date: 2015-08-28, article_date: 2025-06-06
# start_range: 2015-06-29, doc_date: 2015-08-28, article_date: 2025-06-06
# start_range: 2015-06-29, doc_date: 2015-08-28, article_date: 2025-06-06
# start_range: 2015-06-29, doc_date: 2015-08-28, article_date: 2025-06-06
# start_range: 2015-06-29, doc_date: 2015-08-28, article_date: 2025-06-06
# 2015-07-02
# ...
# start_range: 2025-02-27, doc_date: 2025-04-28, article_date: 2025-06-06
# start_range: 2025-02-27, doc_date: 2025-04-28, article_date: 2025-06-06
# start_range: 2025-02-27, doc_date: 2025-04-28, article_date: 2025-06-05
# start_range: 2025-02-27, doc_date: 2025-04-28, article_date: 2025-06-04
# start_range: 2025-02-27, doc_date: 2025-04-28, article_date: 2025-06-04
# start_range: 2025-02-27, doc_date: 2025-04-28, article_date: 2025-06-04
# start_range: 2025-02-27, doc_date: 2025-04-28, article_date: 2025-06-04
# start_range: 2025-02-27, doc_date: 2025-04-28, article_date: 2025-06-04
# start_range: 2025-02-27, doc_date: 2025-04-28, article_date: 2025-06-03
# 2025-02-28
# start_range: 2025-02-28, doc_date: 2025-04-29, article_date: 2025-06-06
# start_range: 2025-02-28, doc_date: 2025-04-29, article_date: 2025-06-06
# start_range: 2025-02-28, doc_date: 2025-04-29, article_date: 2025-06-06
# start_range: 2025-02-28, doc_date: 2025-04-29, article_date: 2025-06-05
# start_range: 2025-02-28, doc_date: 2025-04-29, article_date: 2025-06-04
# start_range: 2025-02-28, doc_date: 2025-04-29, article_date: 2025-06-04
# start_range: 2025-02-28, doc_date: 2025-04-29, article_date: 2025-06-04
# start_range: 2025-02-28, doc_date: 2025-04-29, article_date: 2025-06-04
# start_range: 2025-02-28, doc_date: 2025-04-29, article_date: 2025-06-04
# start_range: 2025-02-28, doc_date: 2025-04-29, article_date: 2025-06-03
# 2025-03-01
# start_range: 2025-03-01, doc_date: 2025-04-30, article_date: 2025-06-06
# start_range: 2025-03-01, doc_date: 2025-04-30, article_date: 2025-06-06
# start_range: 2025-03-01, doc_date: 2025-04-30, article_date: 2025-06-06
# start_range: 2025-03-01, doc_date: 2025-04-30, article_date: 2025-06-05
# start_range: 2025-03-01, doc_date: 2025-04-30, article_date: 2025-06-04
# start_range: 2025-03-01, doc_date: 2025-04-30, article_date: 2025-06-04
# start_range: 2025-03-01, doc_date: 2025-04-30, article_date: 2025-06-04
# start_range: 2025-03-01, doc_date: 2025-04-30, article_date: 2025-06-04
# start_range: 2025-03-01, doc_date: 2025-04-30, article_date: 2025-06-04
# start_range: 2025-03-01, doc_date: 2025-04-30, article_date: 2025-06-03
# 2025-03-02
# start_range: 2025-03-02, doc_date: 2025-05-01, article_date: 2025-06-06
# start_range: 2025-03-02, doc_date: 2025-05-01, article_date: 2025-06-06
# start_range: 2025-03-02, doc_date: 2025-05-01, article_date: 2025-06-06
# start_range: 2025-03-02, doc_date: 2025-05-01, article_date: 2025-06-05
# start_range: 2025-03-02, doc_date: 2025-05-01, article_date: 2025-06-04
# start_range: 2025-03-02, doc_date: 2025-05-01, article_date: 2025-06-04
# start_range: 2025-03-02, doc_date: 2025-05-01, article_date: 2025-06-04
# start_range: 2025-03-02, doc_date: 2025-05-01, article_date: 2025-06-04
# start_range: 2025-03-02, doc_date: 2025-05-01, article_date: 2025-06-04
# start_range: 2025-03-02, doc_date: 2025-05-01, article_date: 2025-06-03
# 2025-03-03
# start_range: 2025-03-03, doc_date: 2025-05-02, article_date: 2025-06-06
# start_range: 2025-03-03, doc_date: 2025-05-02, article_date: 2025-06-06
# start_range: 2025-03-03, doc_date: 2025-05-02, article_date: 2025-06-06
# start_range: 2025-03-03, doc_date: 2025-05-02, article_date: 2025-06-05
# start_range: 2025-03-03, doc_date: 2025-05-02, article_date: 2025-06-04
# start_range: 2025-03-03, doc_date: 2025-05-02, article_date: 2025-06-04
# start_range: 2025-03-03, doc_date: 2025-05-02, article_date: 2025-06-04
# start_range: 2025-03-03, doc_date: 2025-05-02, article_date: 2025-06-04
# start_range: 2025-03-03, doc_date: 2025-05-02, article_date: 2025-06-04
# start_range: 2025-03-03, doc_date: 2025-05-02, article_date: 2025-06-03
# 2025-03-06
# start_range: 2025-03-06, doc_date: 2025-05-05, article_date: 2025-06-06
# start_range: 2025-03-06, doc_date: 2025-05-05, article_date: 2025-06-06
# start_range: 2025-03-06, doc_date: 2025-05-05, article_date: 2025-06-06
# start_range: 2025-03-06, doc_date: 2025-05-05, article_date: 2025-06-05
# start_range: 2025-03-06, doc_date: 2025-05-05, article_date: 2025-06-04
# start_range: 2025-03-06, doc_date: 2025-05-05, article_date: 2025-06-04
# start_range: 2025-03-06, doc_date: 2025-05-05, article_date: 2025-06-04
# start_range: 2025-03-06, doc_date: 2025-05-05, article_date: 2025-06-04
# start_range: 2025-03-06, doc_date: 2025-05-05, article_date: 2025-06-04
# start_range: 2025-03-06, doc_date: 2025-05-05, article_date: 2025-06-03
# 2025-03-07
# start_range: 2025-03-07, doc_date: 2025-05-06, article_date: 2025-06-06
# start_range: 2025-03-07, doc_date: 2025-05-06, article_date: 2025-06-06
# start_range: 2025-03-07, doc_date: 2025-05-06, article_date: 2025-06-06
# start_range: 2025-03-07, doc_date: 2025-05-06, article_date: 2025-06-05
# start_range: 2025-03-07, doc_date: 2025-05-06, article_date: 2025-06-04
# start_range: 2025-03-07, doc_date: 2025-05-06, article_date: 2025-06-04
# start_range: 2025-03-07, doc_date: 2025-05-06, article_date: 2025-06-04
# start_range: 2025-03-07, doc_date: 2025-05-06, article_date: 2025-06-04
# start_range: 2025-03-07, doc_date: 2025-05-06, article_date: 2025-06-04
# start_range: 2025-03-07, doc_date: 2025-05-06, article_date: 2025-06-03
# 2025-03-08
# start_range: 2025-03-08, doc_date: 2025-05-07, article_date: 2025-06-06
# start_range: 2025-03-08, doc_date: 2025-05-07, article_date: 2025-06-06
# start_range: 2025-03-08, doc_date: 2025-05-07, article_date: 2025-06-06
# start_range: 2025-03-08, doc_date: 2025-05-07, article_date: 2025-06-05
# start_range: 2025-03-08, doc_date: 2025-05-07, article_date: 2025-06-04
# start_range: 2025-03-08, doc_date: 2025-05-07, article_date: 2025-06-04
# start_range: 2025-03-08, doc_date: 2025-05-07, article_date: 2025-06-04
# start_range: 2025-03-08, doc_date: 2025-05-07, article_date: 2025-06-04
# start_range: 2025-03-08, doc_date: 2025-05-07, article_date: 2025-06-04
# start_range: 2025-03-08, doc_date: 2025-05-07, article_date: 2025-06-03
# 2025-03-09
# start_range: 2025-03-09, doc_date: 2025-05-08, article_date: 2025-06-06
# start_range: 2025-03-09, doc_date: 2025-05-08, article_date: 2025-06-06
# start_range: 2025-03-09, doc_date: 2025-05-08, article_date: 2025-06-06
# start_range: 2025-03-09, doc_date: 2025-05-08, article_date: 2025-06-05
# start_range: 2025-03-09, doc_date: 2025-05-08, article_date: 2025-06-04
# start_range: 2025-03-09, doc_date: 2025-05-08, article_date: 2025-06-04
# start_range: 2025-03-09, doc_date: 2025-05-08, article_date: 2025-06-04
# start_range: 2025-03-09, doc_date: 2025-05-08, article_date: 2025-06-04
# start_range: 2025-03-09, doc_date: 2025-05-08, article_date: 2025-06-04
# start_range: 2025-03-09, doc_date: 2025-05-08, article_date: 2025-06-03
# 2025-03-10
# start_range: 2025-03-10, doc_date: 2025-05-09, article_date: 2025-06-06
# start_range: 2025-03-10, doc_date: 2025-05-09, article_date: 2025-06-06
# start_range: 2025-03-10, doc_date: 2025-05-09, article_date: 2025-06-06
# start_range: 2025-03-10, doc_date: 2025-05-09, article_date: 2025-06-05
# start_range: 2025-03-10, doc_date: 2025-05-09, article_date: 2025-06-04
# start_range: 2025-03-10, doc_date: 2025-05-09, article_date: 2025-06-04
# start_range: 2025-03-10, doc_date: 2025-05-09, article_date: 2025-06-04
# start_range: 2025-03-10, doc_date: 2025-05-09, article_date: 2025-06-04
# start_range: 2025-03-10, doc_date: 2025-05-09, article_date: 2025-06-04
# start_range: 2025-03-10, doc_date: 2025-05-09, article_date: 2025-06-03
# 2025-03-13
# start_range: 2025-03-13, doc_date: 2025-05-12, article_date: 2025-06-06
# start_range: 2025-03-13, doc_date: 2025-05-12, article_date: 2025-06-06
# start_range: 2025-03-13, doc_date: 2025-05-12, article_date: 2025-06-06
# start_range: 2025-03-13, doc_date: 2025-05-12, article_date: 2025-06-05
# start_range: 2025-03-13, doc_date: 2025-05-12, article_date: 2025-06-04
# start_range: 2025-03-13, doc_date: 2025-05-12, article_date: 2025-06-04
# start_range: 2025-03-13, doc_date: 2025-05-12, article_date: 2025-06-04
# start_range: 2025-03-13, doc_date: 2025-05-12, article_date: 2025-06-04
# start_range: 2025-03-13, doc_date: 2025-05-12, article_date: 2025-06-04
# start_range: 2025-03-13, doc_date: 2025-05-12, article_date: 2025-06-03
# 2025-03-14
# start_range: 2025-03-14, doc_date: 2025-05-13, article_date: 2025-06-06
# start_range: 2025-03-14, doc_date: 2025-05-13, article_date: 2025-06-06
# start_range: 2025-03-14, doc_date: 2025-05-13, article_date: 2025-06-06
# start_range: 2025-03-14, doc_date: 2025-05-13, article_date: 2025-06-05
# start_range: 2025-03-14, doc_date: 2025-05-13, article_date: 2025-06-04
# start_range: 2025-03-14, doc_date: 2025-05-13, article_date: 2025-06-04
# start_range: 2025-03-14, doc_date: 2025-05-13, article_date: 2025-06-04
# start_range: 2025-03-14, doc_date: 2025-05-13, article_date: 2025-06-04
# start_range: 2025-03-14, doc_date: 2025-05-13, article_date: 2025-06-04
# start_range: 2025-03-14, doc_date: 2025-05-13, article_date: 2025-06-03
# 2025-03-15
# start_range: 2025-03-15, doc_date: 2025-05-14, article_date: 2025-06-06
# start_range: 2025-03-15, doc_date: 2025-05-14, article_date: 2025-06-06
# start_range: 2025-03-15, doc_date: 2025-05-14, article_date: 2025-06-06
# start_range: 2025-03-15, doc_date: 2025-05-14, article_date: 2025-06-05
# start_range: 2025-03-15, doc_date: 2025-05-14, article_date: 2025-06-04
# start_range: 2025-03-15, doc_date: 2025-05-14, article_date: 2025-06-04
# start_range: 2025-03-15, doc_date: 2025-05-14, article_date: 2025-06-04
# start_range: 2025-03-15, doc_date: 2025-05-14, article_date: 2025-06-04
# start_range: 2025-03-15, doc_date: 2025-05-14, article_date: 2025-06-04
# start_range: 2025-03-15, doc_date: 2025-05-14, article_date: 2025-06-03
# 2025-03-16
# start_range: 2025-03-16, doc_date: 2025-05-15, article_date: 2025-06-06
# start_range: 2025-03-16, doc_date: 2025-05-15, article_date: 2025-06-06
# start_range: 2025-03-16, doc_date: 2025-05-15, article_date: 2025-06-06
# start_range: 2025-03-16, doc_date: 2025-05-15, article_date: 2025-06-05
# start_range: 2025-03-16, doc_date: 2025-05-15, article_date: 2025-06-04
# start_range: 2025-03-16, doc_date: 2025-05-15, article_date: 2025-06-04
# start_range: 2025-03-16, doc_date: 2025-05-15, article_date: 2025-06-04
# start_range: 2025-03-16, doc_date: 2025-05-15, article_date: 2025-06-04
# start_range: 2025-03-16, doc_date: 2025-05-15, article_date: 2025-06-04
# start_range: 2025-03-16, doc_date: 2025-05-15, article_date: 2025-06-03
# 2025-03-17
# start_range: 2025-03-17, doc_date: 2025-05-16, article_date: 2025-06-06
# start_range: 2025-03-17, doc_date: 2025-05-16, article_date: 2025-06-06
# start_range: 2025-03-17, doc_date: 2025-05-16, article_date: 2025-06-06
# start_range: 2025-03-17, doc_date: 2025-05-16, article_date: 2025-06-05
# start_range: 2025-03-17, doc_date: 2025-05-16, article_date: 2025-06-04
# start_range: 2025-03-17, doc_date: 2025-05-16, article_date: 2025-06-04
# start_range: 2025-03-17, doc_date: 2025-05-16, article_date: 2025-06-04
# start_range: 2025-03-17, doc_date: 2025-05-16, article_date: 2025-06-04
# start_range: 2025-03-17, doc_date: 2025-05-16, article_date: 2025-06-04
# start_range: 2025-03-17, doc_date: 2025-05-16, article_date: 2025-06-03
# 2025-03-20
# start_range: 2025-03-20, doc_date: 2025-05-19, article_date: 2025-06-06
# start_range: 2025-03-20, doc_date: 2025-05-19, article_date: 2025-06-06
# start_range: 2025-03-20, doc_date: 2025-05-19, article_date: 2025-06-06
# start_range: 2025-03-20, doc_date: 2025-05-19, article_date: 2025-06-05
# start_range: 2025-03-20, doc_date: 2025-05-19, article_date: 2025-06-04
# start_range: 2025-03-20, doc_date: 2025-05-19, article_date: 2025-06-04
# start_range: 2025-03-20, doc_date: 2025-05-19, article_date: 2025-06-04
# start_range: 2025-03-20, doc_date: 2025-05-19, article_date: 2025-06-04
# start_range: 2025-03-20, doc_date: 2025-05-19, article_date: 2025-06-04
# start_range: 2025-03-20, doc_date: 2025-05-19, article_date: 2025-06-03
# 2025-03-21
# start_range: 2025-03-21, doc_date: 2025-05-20, article_date: 2025-06-06
# start_range: 2025-03-21, doc_date: 2025-05-20, article_date: 2025-06-06
# start_range: 2025-03-21, doc_date: 2025-05-20, article_date: 2025-06-06
# start_range: 2025-03-21, doc_date: 2025-05-20, article_date: 2025-06-05
# start_range: 2025-03-21, doc_date: 2025-05-20, article_date: 2025-06-04
# start_range: 2025-03-21, doc_date: 2025-05-20, article_date: 2025-06-04
# start_range: 2025-03-21, doc_date: 2025-05-20, article_date: 2025-06-04
# start_range: 2025-03-21, doc_date: 2025-05-20, article_date: 2025-06-04
# start_range: 2025-03-21, doc_date: 2025-05-20, article_date: 2025-06-04
# start_range: 2025-03-21, doc_date: 2025-05-20, article_date: 2025-06-03
# 2025-03-22
# start_range: 2025-03-22, doc_date: 2025-05-21, article_date: 2025-06-06
# start_range: 2025-03-22, doc_date: 2025-05-21, article_date: 2025-06-06
# start_range: 2025-03-22, doc_date: 2025-05-21, article_date: 2025-06-06
# start_range: 2025-03-22, doc_date: 2025-05-21, article_date: 2025-06-05
# start_range: 2025-03-22, doc_date: 2025-05-21, article_date: 2025-06-04
# start_range: 2025-03-22, doc_date: 2025-05-21, article_date: 2025-06-04
# start_range: 2025-03-22, doc_date: 2025-05-21, article_date: 2025-06-04
# start_range: 2025-03-22, doc_date: 2025-05-21, article_date: 2025-06-04
# start_range: 2025-03-22, doc_date: 2025-05-21, article_date: 2025-06-04
# start_range: 2025-03-22, doc_date: 2025-05-21, article_date: 2025-06-03
# 2025-03-23
# start_range: 2025-03-23, doc_date: 2025-05-22, article_date: 2025-06-06
# start_range: 2025-03-23, doc_date: 2025-05-22, article_date: 2025-06-06
# start_range: 2025-03-23, doc_date: 2025-05-22, article_date: 2025-06-06
# start_range: 2025-03-23, doc_date: 2025-05-22, article_date: 2025-06-05
# start_range: 2025-03-23, doc_date: 2025-05-22, article_date: 2025-06-04
# start_range: 2025-03-23, doc_date: 2025-05-22, article_date: 2025-06-04
# start_range: 2025-03-23, doc_date: 2025-05-22, article_date: 2025-06-04
# start_range: 2025-03-23, doc_date: 2025-05-22, article_date: 2025-06-04
# start_range: 2025-03-23, doc_date: 2025-05-22, article_date: 2025-06-04
# start_range: 2025-03-23, doc_date: 2025-05-22, article_date: 2025-06-03
# 2025-03-24
# start_range: 2025-03-24, doc_date: 2025-05-23, article_date: 2025-06-06
# start_range: 2025-03-24, doc_date: 2025-05-23, article_date: 2025-06-06
# start_range: 2025-03-24, doc_date: 2025-05-23, article_date: 2025-06-06
# start_range: 2025-03-24, doc_date: 2025-05-23, article_date: 2025-06-05
# start_range: 2025-03-24, doc_date: 2025-05-23, article_date: 2025-06-04
# start_range: 2025-03-24, doc_date: 2025-05-23, article_date: 2025-06-04
# start_range: 2025-03-24, doc_date: 2025-05-23, article_date: 2025-06-04
# start_range: 2025-03-24, doc_date: 2025-05-23, article_date: 2025-06-04
# start_range: 2025-03-24, doc_date: 2025-05-23, article_date: 2025-06-04
# start_range: 2025-03-24, doc_date: 2025-05-23, article_date: 2025-06-03
# 2025-03-28
# start_range: 2025-03-28, doc_date: 2025-05-27, article_date: 2025-06-06
# start_range: 2025-03-28, doc_date: 2025-05-27, article_date: 2025-06-06
# start_range: 2025-03-28, doc_date: 2025-05-27, article_date: 2025-06-06
# start_range: 2025-03-28, doc_date: 2025-05-27, article_date: 2025-06-05
# start_range: 2025-03-28, doc_date: 2025-05-27, article_date: 2025-06-04
# start_range: 2025-03-28, doc_date: 2025-05-27, article_date: 2025-06-04
# start_range: 2025-03-28, doc_date: 2025-05-27, article_date: 2025-06-04
# start_range: 2025-03-28, doc_date: 2025-05-27, article_date: 2025-06-04
# start_range: 2025-03-28, doc_date: 2025-05-27, article_date: 2025-06-04
# start_range: 2025-03-28, doc_date: 2025-05-27, article_date: 2025-06-03
# 2025-03-29
# start_range: 2025-03-29, doc_date: 2025-05-28, article_date: 2025-06-06
# start_range: 2025-03-29, doc_date: 2025-05-28, article_date: 2025-06-06
# start_range: 2025-03-29, doc_date: 2025-05-28, article_date: 2025-06-06
# start_range: 2025-03-29, doc_date: 2025-05-28, article_date: 2025-06-05
# start_range: 2025-03-29, doc_date: 2025-05-28, article_date: 2025-06-04
# start_range: 2025-03-29, doc_date: 2025-05-28, article_date: 2025-06-04
# start_range: 2025-03-29, doc_date: 2025-05-28, article_date: 2025-06-04
# start_range: 2025-03-29, doc_date: 2025-05-28, article_date: 2025-06-04
# start_range: 2025-03-29, doc_date: 2025-05-28, article_date: 2025-06-04
# start_range: 2025-03-29, doc_date: 2025-05-28, article_date: 2025-06-03

# %%
# Adding the columns for SMA (Simple Moving Average), EMA (Exponential Moving Average), RSI (Relative Strength Index) and MACD ( Moving Average Convergence/Divergence)
print("Adding technical indicators")

tickers = db.Finance_Data.distinct("Ticker")
for symbol in tickers:

    # Converting to list and sorting by date so that each indicator aligns properly
    current = list(db.Finance_Data.find({"Ticker": symbol}).sort("Date",1))
    close = [doc["Close"] for doc in current if "Close" in doc]

    # Skip the first 29 days to avoid NaN values being placed in the database
    if len(close) < 30:
        continue

    npArray = np.array(close)

    SMA_values = ta.SMA(npArray, timeperiod=30)
    EMA_values = ta.EMA(npArray, timeperiod=30)
    RSI_values = ta.RSI(npArray, timeperiod=30)
    MACD_values, MACD_signal, _ = ta.MACD(npArray, fastperiod=10, slowperiod=28, signalperiod=7)


    # Iterating through document to add indicator value.
    for i, doc in enumerate(current):
        # Will be used to store all the key:value pairs for inserting document fields
        insert = {}

        # The second check to make sure there are no NaN values placed in the database
        # There may be a situation where the value is NaN after the 30-day point.

        #SMA
        if i < len(SMA_values) and SMA_values[i] is not np.nan:
            insert["SMA"] = float(EMA_values[i])
        #EMA
        if i < len(EMA_values) and EMA_values[i] is not np.nan:
            insert["EMA"] = float(EMA_values[i])
        #RSI
        if i < len(RSI_values) and RSI_values[i] is not np.nan:
            insert["RSI"] = float(RSI_values[i])
        #MACD
        if i < len(MACD_values) and MACD_values[i] is not np.nan:
            insert["MACD"] = float(MACD_values[i])

        # Insert values for document
        db.Finance_Data.update_one({"_id": doc["_id"]}, {"$set": insert})

print("Finish")

# %%
ntrythei = yf.Ticker("AAPL").news

print(ntrythei)
